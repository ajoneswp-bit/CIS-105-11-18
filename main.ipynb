# %%
import pandas as pd
import re
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import unicodedata
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## 1. Data Acquisition

# %% [markdown]
# **Data Citation:**
# ```
# @article{asai2023selfrag,
#   author    = {Asai, Akari and Wu, Zeqiu and Wang, Yizhong and Sil, Avirup and Hajishirzi, Hannaneh},
#   title     = {{Self-RAG}: Learning to Retrieve, Generate, and Critique through Self-Reflection},
#   year      = {2023},
#   journal   = { arXiv preprint arXiv:2310.11511 },
#   URL       = {https://arxiv.org/abs/2310.11511}
# }
# ```

# %%
# Load data
raw_df = pd.read_json("hf://datasets/selfrag/selfrag_train_data/train.jsonl", lines=True)
raw_df.head()
# Out:
#                                          instruction  \
# 0  In this task, you are given a context paragrap...
# 1  Question: Write a text based on "rangers show ...
# 2  You will be given a sentence. Check whether th...
# 3  Q:Is there a negative or positive tone to this...
# 4  Question: Fertility Clinics Vary on Embryo Dis...
#
#                                               output input             id  \
# 0  [Retrieval]<paragraph>2017 Portland train atta...        flan_v2_88425
# 1  [No Retrieval]six opposition candidates in the...        flan_v2_18667
# 2                 [No Retrieval]1\n****\n[Utility:5]        flan_v2_87754
# 3                  [No Retrieval]Negative[Utility:5]        flan_v2_47789
# 4             [No Retrieval]Answer: World[Utility:5]        flan_v2_10803
#
#   dataset_name
# 0      flan_v2
# 1      flan_v2
# 2      flan_v2
# 3      flan_v2
# 4      flan_v2

# %%
def check_retrieval(output) -> str:
  """Function to denote if retrieval took place when generating an output"""
  if re.search(r"\[Retrieval\]", output):
    return "true"
  elif re.search(r"\[No Retrieval\]", output):
    return "false"
  else:
    # Some outputs are tagged with `[Continue to Use Evidence]` and `Dialog`.
    # We could flag these as false but we will ignore them instead.
    return "null"

# %%
# Apply check retrieval function
raw_df["retrieval"] = raw_df["output"].apply(check_retrieval)

# %%
# Check for balance
raw_df["retrieval"].value_counts()
# Out:
# retrieval
# true     74219
# false    70362
# null      1038
# Name: count, dtype: int64

# %%
# Remove unwanted rows
raw_df.drop(raw_df.loc[raw_df["retrieval"] == "null"].index, inplace=True)
raw_df["retrieval"].value_counts()
# Out:
# retrieval
# true     74219
# false    70362
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Text Cleaning and Preprocessing

# %%
nlp = spacy.load("en_core_web_sm", disable=["ents", "ner", "parser", "pos_"])

# %%
def clean_preprocess(texts):
    with nlp.select_pipes(enable=["tokenizer", "lemmatizer", "attribute_ruler", "tagger"]):
        for doc in nlp.pipe(texts, batch_size=1000, n_process=2):
            tokens = [
                token.lemma_.lower() for token in doc if
                token.is_ascii and
                not token.is_stop and
                not token.is_punct and
                not token.like_email and
                not token.is_space
                ]
            yield " ".join(tokens)

# %%
raw_df["cleaned_instruction"] = list(clean_preprocess(raw_df["instruction"].values))
raw_df.head()
# Out:
#                                          instruction  \
# 0  In this task, you are given a context paragrap...
# 1  Question: Write a text based on "rangers show ...
# 2  You will be given a sentence. Check whether th...
# 3  Q:Is there a negative or positive tone to this...
# 4  Question: Fertility Clinics Vary on Embryo Dis...
#
#                                               output input             id  \
# 0  [Retrieval]<paragraph>2017 Portland train atta...        flan_v2_88425
# 1  [No Retrieval]six opposition candidates in the...        flan_v2_18667
# 2                 [No Retrieval]1\n****\n[Utility:5]        flan_v2_87754
# 3                  [No Retrieval]Negative[Utility:5]        flan_v2_47789
# 4             [No Retrieval]Answer: World[Utility:5]        flan_v2_10803
#
#   dataset_name retrieval                                cleaned_instruction
# 0      flan_v2      true  task given context paragraph tweet question ta...
# 1      flan_v2     false  question write text based rangers iron tie ser...
# 2      flan_v2     false  given sentence check sentence grammatically co...
# 3      flan_v2     false  q negative positive tone product review = = = ...
# 4      flan_v2     false  question fertility clinics vary embryo disposa...

# %%
raw_df.to_csv("cleaned_df.csv", columns=["cleaned_instruction", "retrieval"], index=False)

# %% [markdown]
# ## 3. Feature Engineering

# %%
clean_df = pd.read_csv("https://github.com/Nate-Cheney/CIS-405-RAG_Classifier/raw/refs/heads/main/data/cleaned_df.csv")
clean_df.head()
# Out:
#                                  cleaned_instruction  retrieval
# 0  task given context paragraph tweet question ta...       True
# 1  question write text based rangers iron tie ser...      False
# 2  given sentence check sentence grammatically co...      False
# 3  q negative positive tone product review = = = ...      False
# 4  question fertility clinics vary embryo disposa...      False

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
pool = model.start_multi_process_pool()

# %%
sentences = (clean_df["cleaned_instruction"].tolist())
embeddings = model.encode_multi_process(sentences, pool, show_progress_bar=True)
# Out:
# /tmp/ipython-input-2739182008.py:2: DeprecationWarning: The `encode_multi_process` method has been deprecated, and its functionality has been integrated into `encode`. You can now call `encode` with the same parameters to achieve multi-process encoding.
#   embeddings = model.encode_multi_process(sentences, pool, show_progress_bar=True)
# Chunks:   0%|          | 0/29 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2739182008.py in <cell line: 0>()
#       1 sentences = (clean_df["cleaned_instruction"].tolist())
# ----> 2 embeddings = model.encode_multi_process(sentences, pool, show_progress_bar=True)
#
# /usr/local/lib/python3.12/dist-packages/typing_extensions.py in wrapper(*args, **kwargs)
#    3002                 def wrapper(*args, **kwargs):
#    3003                     warnings.warn(msg, category=category, stacklevel=stacklevel + 1)
# -> 3004                     return arg(*args, **kwargs)
#    3005
#    3006                 if asyncio.coroutines.iscoroutinefunction(arg):
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/SentenceTransformer.py in encode_multi_process(self, sentences, pool, prompt_name, prompt, batch_size, chunk_size, show_progress_bar, precision, normalize_embeddings, truncate_dim)
#    1451                     main()
#    1452         """
# -> 1453         return self.encode(
#    1454             sentences,
#    1455             prompt_name=prompt_name,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#     992         # If pool or a list of devices is provided, use multi-process encoding
#     993         if pool is not None or (isinstance(device, list) and len(device) > 0):
# --> 994             return self._encode_multi_process(
#     995                 sentences,
#     996                 # Utility and post-processing parameters
#
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/SentenceTransformer.py in _encode_multi_process(self, inputs, show_progress_bar, input_was_string, pool, device, chunk_size, **encode_kwargs)
#    1504             # Collect results from the output queue
#    1505             output_list = sorted(
# -> 1506                 [output_queue.get() for _ in trange(chunk_id + 1, desc="Chunks", disable=not show_progress_bar)],
#    1507                 key=lambda x: x[0],
#    1508             )
#
# /usr/lib/python3.12/multiprocessing/queues.py in get(self, block, timeout)
#     101         if block and timeout is None:
#     102             with self._rlock:
# --> 103                 res = self._recv_bytes()
#     104             self._sem.release()
#     105         else:
#
# /usr/lib/python3.12/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# /usr/lib/python3.12/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     428
#     429     def _recv_bytes(self, maxsize=None):
# --> 430         buf = self._recv(4)
#     431         size, = struct.unpack("!i", buf.getvalue())
#     432         if size == -1:
#
# /usr/lib/python3.12/multiprocessing/connection.py in _recv(self, size, read)
#     393         remaining = size
#     394         while remaining > 0:
# --> 395             chunk = read(handle, remaining)
#     396             n = len(chunk)
#     397             if n == 0:
#
# KeyboardInterrupt:

# %%
model.stop_multi_process_pool(pool)

# %%
clean_df["embeddings"]
